# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv'
titanic = pd.read_csv(url)

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic.set_index('PassengerId', inplace=True)

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
gender_counts = titanic['Sex'].value_counts()


plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightpink'])
plt.title('Proporção de Homens e Mulheres no Titanic')
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
colors = {'male': 'blue', 'female': 'pink'}

plt.figure(figsize=(8, 6))
for gender in titanic['Sex'].unique():
    subset = titanic[titanic['Sex'] == gender]
    plt.scatter(subset['Age'], subset['Fare'],
                c=colors[gender], label=gender.capitalize(), alpha=0.6)

plt.xlabel('Idade')
plt.ylabel('Tarifa Paga (Fare)')
plt.title('Scatterplot: Fare vs Age por Gênero')
plt.legend(title='Sexo')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Step 7. How many people survived?

# %%
num_survived = titanic['Survived'].sum()
print(f"Número de sobreviventes: {num_survived}")
# Out:
# Número de sobreviventes: 342

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
plt.figure(figsize=(8, 6))
plt.hist(titanic['Fare'], bins=30, edgecolor='black')
plt.xlabel('Tarifa Paga (Fare)')
plt.ylabel('Número de Passageiros')
plt.title('Histograma da Tarifa Paga (Fare) - Titanic')
plt.grid(True)
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.
